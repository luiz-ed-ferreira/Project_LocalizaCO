# %% [markdown]
# # Data Exploration

# %%
#pip install pandas numpy matplotlib openpyxl

# %%
#Call libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import openpyxl as pxl

#Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Import files df
path = "../Data/"
df_data = pd.read_excel(path + 'data.xlsx')
#df_operations = pd.read_excel(path + 'Dados Operações_ Localiza.xlsm', sheet_name='Export')

# %%
#Analyse data types of the columns in the DataFrames -> If necessary, change the data types of the columns to the correct ones with astypte() method
df_data.dtypes
df_data.head(5)
# Out:
#              Criticidade Regional Região Filial Agência Tipo Filial    Placa  \
# 0      Sit. 35 - Atenção      NDE   NDE2  CONAT   CMNAT         RAC  RUG0F66
# 1  Manut. - Caso Crítico      COE   COE6  COSRS   ACSRS         RAC  SHB0E09
# 2  Manut. - Caso Crítico      SPI   SPI5  CONAS   CMNAS         RAC  RUG9G77
# 3  Manut. - Caso Crítico      SPI   SPI3  COGTA   CMGTA         RAC  RVS3F45
# 4  Manut. - Caso Crítico      COE   COE3  COCAV   CMCAV         RAC  RUD3F49
#
#   Grupo      Fabricante              Modelo  ...           Previsão Ent.  \
# 0    GX            JEEP  RENEGADE LONGITUDE  ...                     NaT
# 1    CE         HYUNDAI    HB20 LIMITED 1.0  ... 2023-02-02 20:19:18.343
# 2     P  GENERAL MOTORS       S10 CD LS 2.8  ... 2023-02-08 20:40:54.380
# 3    LE            JEEP   COMPASS LONGITUDE  ... 2023-03-30 10:39:22.650
# 4    NX            FIAT   NOVA TORO FREEDOM  ... 2023-01-24 16:16:21.770
#
#               Entrada              Envio Orc.     Aprovação Ult. Orc.  \
# 0                 NaT                     NaT                     NaT
# 1 2023-02-03 11:00:00 2023-07-24 10:23:16.143 2023-07-24 10:25:57.500
# 2 2023-02-09 08:51:00 2023-07-24 17:14:13.720 2023-06-09 16:09:04.760
# 3 2023-04-19 12:08:00                     NaT                     NaT
# 4 2023-01-25 16:29:00 2023-07-21 14:09:24.637 2023-07-25 18:39:27.693
#
#         Previsão Peça  Previsão Conclusão Data Conclusão  \
# 0                 NaT                 NaT            NaT
# 1 2023-08-28 16:30:00                 NaT            NaT
# 2                 NaT                 NaT            NaT
# 3 2023-07-18 13:11:00 2023-07-28 17:00:00            NaT
# 4 2023-07-28 17:00:00                 NaT            NaT
#
#    Tempo Desde Ult Monit.                   Ultima Frase Usuário  \
# 0                 Sit. 35                                    NaN
# 1             T: __1 dias               Peça pendente - No prazo
# 2             T: __0 dias      Aguardando aprovação de orçamento
# 3             T: __0 dias  Acionar Montadora (Motivo observação)
# 4             T: __0 dias               Peça Pendente – Atrasada
#
#                                         Retorno Mon.
# 0                                                NaN
# 1  Em 25/07/23 às 15h51: Peça pendente - No prazo...
# 2  Em 26/07/23 às 12h06: Aguardando aprovação de ...
# 3  Em 26/07/23 às 12h27: Acionar Montadora (Motiv...
# 4  Em 26/07/23 às 12h15: Peça Pendente – Atrasada...
#
# [5 rows x 43 columns]

# %%
#Group by and count the number of occurrences of each combination and crate a new DataFrame with the results
df_data_grouped = df_data.groupby(['Filial', 'Criticidade']).size().unstack().replace(np.nan, 0).reset_index()
cols_to_sum = df_data_grouped.columns.difference(['Filial'])
df_data_grouped["Total"] = df_data_grouped[cols_to_sum].sum(axis=1)
df_data_grouped = df_data_grouped.sort_values(by="Total", ascending=False)
df_data_grouped
# Out:
# Criticidade Filial  Manut. - Caso Crítico  Manut. Abaixo 30d  \
# 276          COREC                   35.0              373.0
# 400          COVIX                   21.0              157.0
# 414          COZGG                   42.0              439.0
# 85           COCNF                   30.0              174.0
# 131          COGRU                   36.0              274.0
# ..             ...                    ...                ...
# 296          COSGL                    0.0                2.0
# 343          COTUR                    0.0                3.0
# 366          COUJC                    0.0                2.0
# 153          COITQ                    0.0                0.0
# 314          COSPS                    0.0                0.0
#
# Criticidade  Sit. 35 - Atenção  Sit. 35 - Ok  Total
# 276                      134.0         195.0  737.0
# 400                      319.0         117.0  614.0
# 414                       40.0          68.0  589.0
# 85                       230.0         152.0  586.0
# 131                      136.0         136.0  582.0
# ..                         ...           ...    ...
# 296                        1.0           0.0    3.0
# 343                        0.0           0.0    3.0
# 366                        0.0           0.0    2.0
# 153                        1.0           0.0    1.0
# 314                        1.0           0.0    1.0
#
# [430 rows x 6 columns]
