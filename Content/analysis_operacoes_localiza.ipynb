# %% [markdown]
# # Data Exploration

# %%
#Call libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import openpyxl as pxl

#Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Import files df
path = "../Data/"
df_data = pd.read_excel(path + 'Dados Operações_ Localiza.xlsm', sheet_name='Export')
df_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 49 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Fornecedor                    666 non-null    str
#  1   Capacidade                    665 non-null    float64
#  2   Ocupação (%)                  635 non-null    float64
#  3   Qtd. Carro (Dia)              665 non-null    float64
#  4   Qtd. SS                       665 non-null    float64
#  5   Qtd. SS PT                    0 non-null      float64
#  6   Qtd. SS Sem Orc.              551 non-null    str
#  7   Qtd. Peça Externa             407 non-null    float64
#  8   Qtd. Peça Interna             542 non-null    float64
#  9   Tempo Agendamento             642 non-null    str
#  10  Qtd. Placas                   642 non-null    float64
#  11  Peso (%)                      642 non-null    float64
#  12  Tempo Retirada Filial         579 non-null    str
# ...
