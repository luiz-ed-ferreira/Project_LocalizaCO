# %% [markdown]
# # Data Exploration

# %%
#pip install pandas numpy matplotlib openpyxl

# %%
#Call libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import openpyxl as pxl

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Import files df
df_data = pd.read_excel('../Data/data.xlsx')
df_operations = pd.read_excel('../Data/Dados Operações_ Localiza.xlsm', sheet_name='Export')

# %%
df_operations
# Out:
#                                             Fornecedor  Capacidade  \
# 0                   STARK AUTO CENTER - 29981267000199         3.0
# 1                  SERV FROTA - MÓVEL - 14354312000108        30.0
# 2                          STUDIO CAR - 26057948000177         1.0
# 3                 AUTO CENTER SHOPPIN - 10250932000146         5.0
# 4          AMAZONAS MULTIMARCAS-INTER - 17324331000422        40.0
# ..                                                 ...         ...
# 662    SINAL (RENAULT) - NAÇÕES UNIDA - 12502665000697         0.0
# 663                 WILLZ - NAPAS CAR - 23586628000116         0.0
# 664                                              Total    251766.0
# 665                                                NaN         NaN
# 666  Applied filters:\nQTD SS is not blank\nNOME FA...         NaN
#
#      Ocupação (%)  Qtd. Carro (Dia)  Qtd. SS  Qtd. SS PT Qtd. SS Sem Orc.  \
# 0        0.718721          2.156164    981.0         NaN        141 (14%)
# 1        0.503744         15.112329   6999.0         NaN      6.156 (88%)
# 2        0.367123          0.367123    169.0         NaN         44 (26%)
# 3        0.337534          1.687671    725.0         NaN        158 (22%)
# 4        0.177329          7.093151   3269.0         NaN      1.914 (59%)
# ..            ...               ...      ...         ...              ...
# 662           NaN          0.002740      1.0         NaN              NaN
# 663           NaN          0.002740      1.0         NaN              NaN
# 664      0.000235         59.104110  72616.0         NaN     29.876 (41%)
# 665           NaN               NaN      NaN         NaN              NaN
# 666           NaN               NaN      NaN         NaN              NaN
#
#      Qtd. Peça Externa  Qtd. Peça Interna Tempo Agendamento  ...  \
# 0                 27.0             3240.0   0 dias 04:22:58  ...
# 1                177.0              545.0   0 dias 18:05:58  ...
# 2                192.0              370.0   2 dias 07:12:10  ...
# 3                891.0             1574.0   2 dias 04:05:07  ...
# 4                100.0             2595.0   2 dias 02:47:57  ...
# ..                 ...                ...               ...  ...
# 662                NaN                3.0  21 dias 02:15:44  ...
# 663                1.0               15.0               NaN  ...
# 664            39144.0            85409.0   2 dias 03:58:48  ...
# 665                NaN                NaN               NaN  ...
# 666                NaN                NaN               NaN  ...
#
#      Qtd. SS (0 a 5 Dias)  Qtd. SS (6 a 10 Dias) Qtd. SS (11 a 15 Dias)  \
# 0                   883.0                   23.0                    8.0
# 1                  6453.0                  165.0                   86.0
# 2                    55.0                   29.0                   25.0
# 3                   140.0                  195.0                  101.0
# 4                  1829.0                  560.0                  247.0
# ..                    ...                    ...                    ...
# 662                   NaN                    NaN                    NaN
# 663                   NaN                    NaN                    NaN
# 664               39864.0                 8676.0                 4731.0
# 665                   NaN                    NaN                    NaN
# 666                   NaN                    NaN                    NaN
#
#      Qtd. SS (16 a 30 Dias)  Qtd. SS (Acima de 31 Dias)  \
# 0                       3.0                         1.0
# 1                      71.0                        44.0
# 2                      22.0                        23.0
# 3                     107.0                        85.0
# 4                     262.0                       163.0
# ..                      ...                         ...
# 662                     NaN                         1.0
# 663                     NaN                         1.0
# 664                  5851.0                      4904.0
# 665                     NaN                         NaN
# 666                     NaN                         NaN
#
#     Qtd. SS (Orc. 0 a 300)  Qtd. SS (Orc. 301 a 1000)  \
# 0                    912.0                       67.0
# 1                   6998.0                        1.0
# 2                     95.0                       43.0
# 3                    383.0                      221.0
# 4                   2732.0                      335.0
# ..                     ...                        ...
# 662                    NaN                        NaN
# 663                    NaN                        NaN
# 664                48063.0                    16491.0
# 665                    NaN                        NaN
# 666                    NaN                        NaN
#
#      Qtd. SS (Orc. 1001 a 2000) Qtd. SS (Orc. Acima de 2000)  \
# 0                           2.0                          NaN
# 1                           NaN                          NaN
# 2                          18.0                         13.0
# 3                          76.0                         45.0
# 4                         184.0                         18.0
# ..                          ...                          ...
# 662                         NaN                          1.0
# 663                         NaN                          1.0
# 664                      5692.0                       2370.0
# 665                         NaN                          NaN
# 666                         NaN                          NaN
#
#                          Cidade
# 0                SAO PAULO - SP
# 1              SANTO ANDRE - SP
# 2                SAO PAULO - SP
# 3                SAO PAULO - SP
# 4                SAO PAULO - SP
# ..                          ...
# 662              SAO PAULO - SP
# 663  SAO BERNARDO DO CAMPO - SP
# 664                          -
# 665                         NaN
# 666                         NaN
#
# [667 rows x 49 columns]
